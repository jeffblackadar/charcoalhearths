# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffblackadar/charcoalhearths/blob/master/laszip_install.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
git clone https://github.com/LASzip/LASzip.git
git tag #List tags
git checkout tags/2.0.2
./configure
make
sudo make install

# %%
# !git clone https://github.com/LASzip/LASzip.git
# Out:
# Cloning into 'LASzip'...
# remote: Enumerating objects: 4385, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 4385 (delta 44), reused 82 (delta 43), pack-reused 4299
# Receiving objects: 100% (4385/4385), 1.40 MiB | 19.65 MiB/s, done.
# Resolving deltas: 100% (2976/2976), done.

# %%
# %cd /content/LASzip
# Out:
# /content/LASzip

# %%
# !git tag
# Out:
# 1.0.1
# 1.2.0
# 2.0.0
# 2.0.1
# 2.0.2
# 3.1.0
# 3.1.1
# 3.2.0
# 3.2.1
# 3.2.2
# 3.2.8
# 3.2.9
# 3.3.0
# 3.3.1
# 3.4.0
# 3.4.1
# 3.4.3
# debian/precise/2.2.0-1
# v2.2.0

# %%
# !git checkout tags/3.4.3
# Out:
# Note: checking out 'tags/3.4.3'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by performing another checkout.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -b with the checkout command again. Example:
#
#   git checkout -b <new-branch-name>
#
# HEAD is now at 1ab671e increment versions to 3.4.3 in preparation for release

# %%
# !cmake /content/LASzip
# Out:
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /content/LASzip

# %%
# !make
# Out:
# Scanning dependencies of target laszip
# [  4%] Building CXX object src/CMakeFiles/laszip.dir/arithmeticdecoder.cpp.o
# [  8%] Building CXX object src/CMakeFiles/laszip.dir/arithmeticencoder.cpp.o
# [ 13%] Building CXX object src/CMakeFiles/laszip.dir/arithmeticmodel.cpp.o
# [ 17%] Building CXX object src/CMakeFiles/laszip.dir/integercompressor.cpp.o
# [ 21%] Building CXX object src/CMakeFiles/laszip.dir/lasindex.cpp.o
# [ 26%] Building CXX object src/CMakeFiles/laszip.dir/lasinterval.cpp.o
# [ 30%] Building CXX object src/CMakeFiles/laszip.dir/lasquadtree.cpp.o
# [ 34%] Building CXX object src/CMakeFiles/laszip.dir/lasreaditemcompressed_v1.cpp.o
# /content/LASzip/src/lasreaditemcompressed_v1.cpp: In member function ‘virtual BOOL LASreadItemCompressed_GPSTIME11_v1::init(const U8*, U32&)’:
# ...

# %%
# !sudo make install
# Out:
# [ 91%] Built target laszip
# [100%] Built target laszip_api
# Install the project...
# -- Install configuration: ""
# -- Installing: /usr/local/lib/liblaszip.so.8.0.5
# -- Installing: /usr/local/lib/liblaszip.so.8
# -- Set runtime path of "/usr/local/lib/liblaszip.so.8.0.5" to "/usr/local/lib"
# -- Installing: /usr/local/lib/liblaszip.so
# -- Installing: /usr/local/lib/liblaszip_api.so.8.0.5
# -- Installing: /usr/local/lib/liblaszip_api.so.8
# -- Set runtime path of "/usr/local/lib/liblaszip_api.so.8.0.5" to "/usr/local/lib"
# -- Installing: /usr/local/lib/liblaszip_api.so
# -- Installing: /usr/local/include/laszip/laszip_api.h
# -- Installing: /usr/local/include/laszip/laszip_api_version.h

# %%
# !laszip -h
# Out:
# /bin/bash: laszip: command not found
