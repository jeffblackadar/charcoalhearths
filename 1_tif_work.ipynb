# %%
my_tif = '/storage/charcoalhearths/tifs/BlueMtHearthforShawnJeff.tif'

import cv2
import matplotlib.pyplot as plt 

image = cv2.imread(my_tif, cv2.IMREAD_UNCHANGED)
print(image.dtype) 
print(image.shape) 
print(image[1,1])
plt.imshow(image)
plt.show()
plt.imshow(image, cmap="gray", vmin=0, vmax=4096)
plt.show()
# Out:
# float32
# (1091, 1452)
# -9999.0
